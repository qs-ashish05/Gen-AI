# %%
# recommended to run in google colab

# %%
import os
os.environ["HF_TOKEN"] = "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"

# %%
model_id ="google/gemma-3-1b-it"

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]

# %%
print(tokenizer("Hello my name is ashish"))
# Out:
# {'input_ids': [2, 9259, 1041, 1463, 563, 29359, 1044], 'attention_mask': [1, 1, 1, 1, 1, 1, 1]}

# %%
# tokenizer.get_vocab() # return the list of vocab words
len(tokenizer.get_vocab())
# Out:
# 262145

# %%
input_token = tokenizer("How was the match today?")["input_ids"]
print(input_token)
# Out:
# [2, 3910, 691, 506, 4241, 3124, 236881]

# %% [markdown]
# ## Model running

# %%
from transformers import AutoModelForCausalLM
# CausalLm means the basic gpt model that predicts the next word token

# %%
model = AutoModelForCausalLM.from_pretrained(model_id, )
# Out:
# config.json:   0%|          | 0.00/899 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]

# %%
# import torch

# model = AutoModelForCausalLM.from_pretrained(
#     model_id,
#     torch_dtype = torch.bfloat16
# )

# %%
from transformers import pipeline

# %%
gen_pipeline = pipeline("text-generation", model=model, tokenizer = tokenizer)
# Out:
# Device set to use cpu

# %%
gen_pipeline("hey there", max_new_tokens = 25)
# Out:
# [{'generated_text': "hey there!\n\nI understand you're looking for help with a topic.\n\nLet's start with the basics. Can you"}]

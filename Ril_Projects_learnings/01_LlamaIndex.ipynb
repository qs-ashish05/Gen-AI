# %% [markdown]
# * Llama Index: Open source project framework for creating LLM based applications
# * LlamaIndex was used for the integration of custom data resources wiith the large langiage models
# * reference - https://www.radicalloop.com/blog/simplifying-large-language-models-an-exploration-of-llama-index
# * The workflow of LlamaIndex can be understanded in the following way
#
# ![image.png](data:image/png;base64,...)
